# %%
import pandas as pd

# %%
df = pd.read_csv('photon_data.csv')

# %%
df.head()
# Out:
#    i  j  q0_t    q0_r     q0_th  q0_ph      p0_t      p0_r     p0_th  \
# 0  0  0   0.0  2500.0  1.570796    0.0 -0.969568 -0.970344  0.170927
# 1  0  1   0.0  2500.0  1.570796    0.0 -0.969625 -0.970401  0.170937
# 2  0  2   0.0  2500.0  1.570796    0.0 -0.969681 -0.970458  0.170947
# 3  0  3   0.0  2500.0  1.570796    0.0 -0.969738 -0.970514  0.170957
# 4  0  4   0.0  2500.0  1.570796    0.0 -0.969794 -0.970570  0.170967
#
#       p0_ph       final_r  final_th  final_ph collision  bg_u  bg_v  rgb
# 0 -0.170927  54722.763116  2.037461 -2.604695    escape   NaN   NaN  NaN
# 1 -0.170595  54666.833134  2.038004 -2.605090    escape   NaN   NaN  NaN
# 2 -0.170262  54610.950838  2.038547 -2.605486    escape   NaN   NaN  NaN
# 3 -0.169930  54555.116433  2.039091 -2.605884    escape   NaN   NaN  NaN
# 4 -0.169598  54499.330123  2.039636 -2.606283    escape   NaN   NaN  NaN
